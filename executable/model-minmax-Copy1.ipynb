# %% [markdown]
# ### setup

# %%
import os
import argparse
import pickle
import time

import numpy as np; np.seterr(invalid='ignore')
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
from torch.optim.lr_scheduler import MultiStepLR
from torch.utils.data import TensorDataset, DataLoader

# %%
parser = {
    'data_path': '../data/wttsf/',
    'train_file': 'train_1.csv',
    'key_file': 'key_1.csv',
    'intermediate_path': '../intermediate/30082017/',
    'n_epoch': 4,
    'future': 70,
    'batch_size': 128,
    'hidden_size': 256,
    'log_every': 10,
    'read_from_file': False,
    'train': True,
    'model_name': '',
    'cuda': True,
    'seed': 30082017,
}
args = argparse.Namespace(**parser)

args.cuda = args.cuda and torch.cuda.is_available()
torch.manual_seed(args.seed);

# %% [markdown]
# ### model

# %%
class DenseLSTMForecast(nn.Module):
    def __init__(self, hidden_size):
        super(DenseLSTMForecast, self).__init__()
        self.lstm1 = nn.LSTMCell(1, hidden_size, bias=False)
        self.lstm2 = nn.LSTMCell(hidden_size+1, hidden_size, bias=False)
        self.lstm3 = nn.LSTMCell(2*hidden_size+1, hidden_size, bias=False)
        self.linear = nn.Linear(3*hidden_size+1, 1, bias=False)
        self.hidden_size = hidden_size

    def forward(self, x, future=1):
        o = []
        tt = torch.cuda if args.cuda else torch
        h1_t = Variable(tt.FloatTensor(x.size(0), self.hidden_size).zero_())
        c1_t = Variable(tt.FloatTensor(x.size(0), self.hidden_size).zero_())
        h2_t = Variable(tt.FloatTensor(x.size(0), self.hidden_size).zero_())
        c2_t = Variable(tt.FloatTensor(x.size(0), self.hidden_size).zero_())
        h3_t = Variable(tt.FloatTensor(x.size(0), self.hidden_size).zero_())
        c3_t = Variable(tt.FloatTensor(x.size(0), self.hidden_size).zero_())
        
        for x_t in x.chunk(x.size(1), dim=1):
            x_t = x_t.squeeze(dim=1)
            h1_t, c1_t = self.lstm1(x_t, (h1_t, c1_t))
            h1d_t = torch.cat([x_t, h1_t], dim=1)
            h2_t, c2_t = self.lstm2(h1d_t, (h2_t, c2_t))
            h2d_t = torch.cat([x_t, h1_t, h2_t], dim=1)
            h3_t, c3_t = self.lstm3(h2d_t, (h3_t, c3_t))
            h3d_t = torch.cat([x_t, h1_t, h2_t, h3_t], dim=1)
            o_t = self.linear(h3d_t)
            o.append(o_t)
            
        for i in range(future-1):
            h1_t, c1_t = self.lstm1(o_t, (h1_t, c1_t))
            h1d_t = torch.cat([o_t, h1_t], dim=1)
            h2_t, c2_t = self.lstm2(h1d_t, (h2_t, c2_t))
            h2d_t = torch.cat([o_t, h1_t, h2_t], dim=1)
            h3_t, c3_t = self.lstm3(h2d_t, (h3_t, c3_t))
            h3d_t = torch.cat([o_t, h1_t, h2_t, h3_t], dim=1)
            o_t = self.linear(h3d_t)
            o.append(o_t)

        return torch.stack(o, dim=1)

# %% [markdown]
# ### utils

# %%
def smape(y_pred, y_true):
    raw_smape = np.abs(y_true - y_pred) / (np.abs(y_true) + np.abs(y_pred))
    kaggle_smape = np.nan_to_num(raw_smape)
    return np.mean(kaggle_smape) * 200

# %%
def get_data():
    raw_data_file = os.path.join(args.intermediate_path,
                                 'raw_data.pkl')
    scaled_data_file = os.path.join(args.intermediate_path,
                                    'scaled_data.pkl')
    scaler_file = os.path.join(args.intermediate_path, 'scaler.pkl')
    if not args.read_from_file:
        data_df = pd.read_csv(os.path.join(args.data_path, args.train_file),
                              index_col='Page')
        raw_data = np.nan_to_num(data_df.values.astype('float32'))
        data = np.log1p(raw_data)
        scaler = StandardScaler()
        scaler.fit(np.swapaxes(data[:, :-args.future], 0, 1))
        scaled_data = scaler.transform(np.swapaxes(data, 0, 1))
        scaled_data = np.swapaxes(scaled_data, 0, 1)
        
        with open(raw_data_file, 'wb') as f:
            pickle.dump(raw_data, f)
        with open(scaled_data_file, 'wb') as f:
            pickle.dump(scaled_data, f)
        with open(scaler_file, 'wb') as f:
            pickle.dump(scaler, f)
    else:
        with open(raw_data_file, 'rb') as f:
            raw_data = pickle.load(f)
        with open(scaled_data_file, 'rb') as f:
            scaled_data = pickle.load(f)
        with open(scaler_file, 'rb') as f:
            scaler = pickle.load(f)
    return raw_data, scaled_data, scaler

# %%
def train(raw_data, scaled_data, scaler, model, criterion, optimizer, epoch):
    print("=> EPOCH {}".format(epoch))
    p = np.random.permutation(raw_data.shape[0])
    inverse_p = np.argsort(p)
    
    input_tensor = torch.from_numpy(scaled_data[p, :-1]).unsqueeze(2)
    target_tensor = torch.from_numpy(scaled_data[p, 1:]).unsqueeze(2)
    dataset = TensorDataset(input_tensor, target_tensor)
    data_loader = DataLoader(dataset, args.batch_size)
    
    train_loss = 0
    val_output_list = []
    init_time = time.time()
    for i, (inputt, target) in enumerate(data_loader):
        if args.cuda:
            inputt = inputt.cuda()
            target = target.cuda()
        inputt = Variable(inputt)
        target = Variable(target)
        
        output = model(inputt)
        pos = np.random.randint(args.future, output.size(1)-2*args.future)
        loss = criterion(output[:, pos:pos+args.future],
                         target[:, pos:pos+args.future])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.data[0] * inputt.size(0)
        val_output_list.append(output[:,-args.future:]
                               .data.squeeze(2).cpu().numpy())
        
        if i % args.log_every == 0:
            print("   % Time: {:4.0f}s | Batch: {:4} | Loss: {:.4f}"
                  .format(time.time()-init_time, i+1, loss.data[0]))
        
    val_output_all = np.concatenate(val_output_list, axis=0)[inverse_p]
    prediction = np.swapaxes(scaler.inverse_transform(
            np.swapaxes(val_output_all, 0, 1)), 0, 1)
    prediction = np.exp(prediction) - 1
    prediction[prediction < 0] = 0
    prediction = np.around(prediction)
    
    train_loss /= raw_data.shape[0]
    val_loss = smape(prediction, raw_data[:, -args.future:])
    
    print("="*10)
    print("   % Epoch: {} | Time: {:4.0f}s | "
          "Train loss: {:.4f} | Val loss: {:.4f}"
          .format(epoch, time.time()-init_time, train_loss , val_loss))
    print("="*10)
    return val_loss

# %%
def forecast(scaled_data, scaler, model):
    input_tensor = torch.from_numpy(scaled_data).unsqueeze(2)
    target_tensor = torch.zeros(input_tensor.size(0))
    dataset = torch.utils.data.TensorDataset(input_tensor, target_tensor)
    data_loader = DataLoader(dataset, args.batch_size)
    
    output_list = []
    for inputt, _ in data_loader:
        if args.cuda:
            inputt = inputt.cuda()
        inputt = Variable(inputt)
        output = model(inputt, args.future)
        output_list.append(output.data.squeeze(2).cpu().numpy()
                           [:, -args.future:])
        
    output_all = np.concatenate(output_list, axis=0)
    prediction = np.swapaxes(scaler.inverse_transform(
            np.swapaxes(output_all, 0, 1)), 0, 1)
    prediction = np.exp(prediction) - 1
    prediction[prediction < 0] = 0
    prediction = np.around(prediction)
    return prediction

# %%
def save_model(model, epoch, val_loss):
    model_file = os.path.join(args.intermediate_path,
                              "model_seed{}_epoch{}_loss_{:.4f}.pth"
                              .format(args.seed, epoch, val_loss))
    torch.save(model.state_dict(), os.path.join(model_file))

# %% [markdown]
# ### prepare

# %%
raw_data, scaled_data, scaler = get_data()

# %%
model = DenseLSTMForecast(args.hidden_size)
if args.cuda:
    model.cuda()
criterion = nn.L1Loss()

# %%
optimizer = optim.Adam(model.parameters())
scheduler = MultiStepLR(optimizer, milestones=[args.n_epoch-1])

# %% [markdown]
# ### train

# %%
if args.train:
    for epoch in range(1, args.n_epoch+1):
        scheduler.step()
        val_loss = train(raw_data, scaled_data, scaler,
                         model, criterion, optimizer, epoch)
        save_model(model, epoch, val_loss)
else:
    model_file = os.path.join(args.intermediate_path, args.model_name)
    model.load_state_dict(torch.load(model_file))
# Out:
# => EPOCH 1
#    % Time:    3s | Batch:    1 | Loss: 0.6801
#    % Time:   25s | Batch:   11 | Loss: 0.4810
#    % Time:   47s | Batch:   21 | Loss: 0.4567
#    % Time:   70s | Batch:   31 | Loss: 0.4757
#    % Time:   92s | Batch:   41 | Loss: 0.4790
#    % Time:  114s | Batch:   51 | Loss: 0.4529
#    % Time:  136s | Batch:   61 | Loss: 0.4489
#    % Time:  158s | Batch:   71 | Loss: 0.4643
#    % Time:  180s | Batch:   81 | Loss: 0.4241
#    % Time:  202s | Batch:   91 | Loss: 0.4407
#    % Time:  224s | Batch:  101 | Loss: 0.4369
#    % Time:  246s | Batch:  111 | Loss: 0.4258
#    % Time:  269s | Batch:  121 | Loss: 0.4319
#    % Time:  291s | Batch:  131 | Loss: 0.4335
#    % Time:  313s | Batch:  141 | Loss: 0.4485
#    % Time:  335s | Batch:  151 | Loss: 0.4288
#    % Time:  358s | Batch:  161 | Loss: 0.4408
#    % Time:  380s | Batch:  171 | Loss: 0.3934
#    % Time:  402s | Batch:  181 | Loss: 0.4275
#    % Time:  425s | Batch:  191 | Loss: 0.3846
#    % Time:  447s | Batch:  201 | Loss: 0.4490
#    % Time:  469s | Batch:  211 | Loss: 0.4383
#    % Time:  491s | Batch:  221 | Loss: 0.4522
#    % Time:  514s | Batch:  231 | Loss: 0.3829
#    % Time:  536s | Batch:  241 | Loss: 0.4210
#    % Time:  558s | Batch:  251 | Loss: 0.4084
#    % Time:  580s | Batch:  261 | Loss: 0.4198
#    % Time:  603s | Batch:  271 | Loss: 0.4388
#    % Time:  625s | Batch:  281 | Loss: 0.4430
#    % Time:  647s | Batch:  291 | Loss: 0.4034
#    % Time:  669s | Batch:  301 | Loss: 0.4145
#    % Time:  692s | Batch:  311 | Loss: 0.4094
#    % Time:  713s | Batch:  321 | Loss: 0.3789
#    % Time:  735s | Batch:  331 | Loss: 0.3821
#    % Time:  757s | Batch:  341 | Loss: 0.4334
#    % Time:  779s | Batch:  351 | Loss: 0.3912
#    % Time:  801s | Batch:  361 | Loss: 0.3725
#    % Time:  823s | Batch:  371 | Loss: 0.4119
#    % Time:  845s | Batch:  381 | Loss: 0.3714
#    % Time:  867s | Batch:  391 | Loss: 0.4073
#    % Time:  889s | Batch:  401 | Loss: 0.3812
#    % Time:  912s | Batch:  411 | Loss: 0.4161
#    % Time:  934s | Batch:  421 | Loss: 0.3873
#    % Time:  956s | Batch:  431 | Loss: 0.3869
#    % Time:  979s | Batch:  441 | Loss: 0.4036
#    % Time: 1001s | Batch:  451 | Loss: 0.3894
#    % Time: 1023s | Batch:  461 | Loss: 0.3905
#    % Time: 1045s | Batch:  471 | Loss: 0.4214
#    % Time: 1068s | Batch:  481 | Loss: 0.4216
#    % Time: 1090s | Batch:  491 | Loss: 0.3605
#    % Time: 1112s | Batch:  501 | Loss: 0.3926
#    % Time: 1134s | Batch:  511 | Loss: 0.3912
#    % Time: 1157s | Batch:  521 | Loss: 0.3866
#    % Time: 1179s | Batch:  531 | Loss: 0.3973
#    % Time: 1201s | Batch:  541 | Loss: 0.3847
#    % Time: 1223s | Batch:  551 | Loss: 0.3783
#    % Time: 1245s | Batch:  561 | Loss: 0.4101
#    % Time: 1267s | Batch:  571 | Loss: 0.4046
#    % Time: 1289s | Batch:  581 | Loss: 0.4063
#    % Time: 1311s | Batch:  591 | Loss: 0.3754
#    % Time: 1333s | Batch:  601 | Loss: 0.3902
#    % Time: 1355s | Batch:  611 | Loss: 0.3829
#    % Time: 1377s | Batch:  621 | Loss: 0.3975
#    % Time: 1400s | Batch:  631 | Loss: 0.4101
#    % Time: 1422s | Batch:  641 | Loss: 0.4003
#    % Time: 1444s | Batch:  651 | Loss: 0.3642
#    % Time: 1467s | Batch:  661 | Loss: 0.3920
#    % Time: 1489s | Batch:  671 | Loss: 0.3695
#    % Time: 1511s | Batch:  681 | Loss: 0.4277
#    % Time: 1532s | Batch:  691 | Loss: 0.4189
#    % Time: 1554s | Batch:  701 | Loss: 0.3342
#    % Time: 1576s | Batch:  711 | Loss: 0.3812
#    % Time: 1598s | Batch:  721 | Loss: 0.3899
#    % Time: 1620s | Batch:  731 | Loss: 0.3941
#    % Time: 1642s | Batch:  741 | Loss: 0.4037
#    % Time: 1664s | Batch:  751 | Loss: 0.4033
#    % Time: 1686s | Batch:  761 | Loss: 0.3396
#    % Time: 1708s | Batch:  771 | Loss: 0.3710
#    % Time: 1730s | Batch:  781 | Loss: 0.3651
#    % Time: 1752s | Batch:  791 | Loss: 0.3726
#    % Time: 1774s | Batch:  801 | Loss: 0.3927
#    % Time: 1796s | Batch:  811 | Loss: 0.3835
#    % Time: 1818s | Batch:  821 | Loss: 0.4138
#    % Time: 1840s | Batch:  831 | Loss: 0.4039
#    % Time: 1862s | Batch:  841 | Loss: 0.4078
#    % Time: 1884s | Batch:  851 | Loss: 0.3555
#    % Time: 1906s | Batch:  861 | Loss: 0.4309
#    % Time: 1928s | Batch:  871 | Loss: 0.3487
#    % Time: 1950s | Batch:  881 | Loss: 0.3857
#    % Time: 1973s | Batch:  891 | Loss: 0.3674
#    % Time: 1995s | Batch:  901 | Loss: 0.3838
#    % Time: 2017s | Batch:  911 | Loss: 0.3979
#    % Time: 2039s | Batch:  921 | Loss: 0.3934
#    % Time: 2062s | Batch:  931 | Loss: 0.3973
#    % Time: 2084s | Batch:  941 | Loss: 0.3773
#    % Time: 2106s | Batch:  951 | Loss: 0.4025
#    % Time: 2128s | Batch:  961 | Loss: 0.4092
#    % Time: 2150s | Batch:  971 | Loss: 0.3574
#    % Time: 2172s | Batch:  981 | Loss: 0.3928
#    % Time: 2194s | Batch:  991 | Loss: 0.3959
#    % Time: 2216s | Batch: 1001 | Loss: 0.3743
#    % Time: 2238s | Batch: 1011 | Loss: 0.3979
#    % Time: 2260s | Batch: 1021 | Loss: 0.3917
#    % Time: 2282s | Batch: 1031 | Loss: 0.4031
#    % Time: 2304s | Batch: 1041 | Loss: 0.3736
#    % Time: 2326s | Batch: 1051 | Loss: 0.3912
#    % Time: 2348s | Batch: 1061 | Loss: 0.3919
#    % Time: 2370s | Batch: 1071 | Loss: 0.3893
#    % Time: 2392s | Batch: 1081 | Loss: 0.3835
#    % Time: 2414s | Batch: 1091 | Loss: 0.3797
#    % Time: 2436s | Batch: 1101 | Loss: 0.3879
#    % Time: 2458s | Batch: 1111 | Loss: 0.3897
#    % Time: 2480s | Batch: 1121 | Loss: 0.3954
#    % Time: 2502s | Batch: 1131 | Loss: 0.4200
# ==========
#    % Epoch: 1 | Time: 2509s | Train loss: 0.4057 | Val loss: 30.7498
# ==========
# => EPOCH 2
#    % Time:    2s | Batch:    1 | Loss: 0.4000
#    % Time:   24s | Batch:   11 | Loss: 0.3885
#    % Time:   46s | Batch:   21 | Loss: 0.4113
#    % Time:   68s | Batch:   31 | Loss: 0.4210
#    % Time:   90s | Batch:   41 | Loss: 0.3793
#    % Time:  112s | Batch:   51 | Loss: 0.3846
#    % Time:  134s | Batch:   61 | Loss: 0.3744
#    % Time:  156s | Batch:   71 | Loss: 0.3866
#    % Time:  178s | Batch:   81 | Loss: 0.3846
#    % Time:  200s | Batch:   91 | Loss: 0.4179
#    % Time:  223s | Batch:  101 | Loss: 0.4317
#    % Time:  245s | Batch:  111 | Loss: 0.3629
#    % Time:  267s | Batch:  121 | Loss: 0.4077
#    % Time:  289s | Batch:  131 | Loss: 0.3525
#    % Time:  312s | Batch:  141 | Loss: 0.4043
#    % Time:  334s | Batch:  151 | Loss: 0.4139
#    % Time:  356s | Batch:  161 | Loss: 0.4001
#    % Time:  378s | Batch:  171 | Loss: 0.3552
#    % Time:  401s | Batch:  181 | Loss: 0.3730
#    % Time:  423s | Batch:  191 | Loss: 0.4195
#    % Time:  445s | Batch:  201 | Loss: 0.3840
#    % Time:  468s | Batch:  211 | Loss: 0.3930
#    % Time:  490s | Batch:  221 | Loss: 0.3920
#    % Time:  512s | Batch:  231 | Loss: 0.4188
#    % Time:  534s | Batch:  241 | Loss: 0.3814
#    % Time:  556s | Batch:  251 | Loss: 0.4113
#    % Time:  578s | Batch:  261 | Loss: 0.3845
#    % Time:  601s | Batch:  271 | Loss: 0.4252
#    % Time:  623s | Batch:  281 | Loss: 0.3782
#    % Time:  645s | Batch:  291 | Loss: 0.3396
#    % Time:  667s | Batch:  301 | Loss: 0.4138
#    % Time:  689s | Batch:  311 | Loss: 0.3657
#    % Time:  711s | Batch:  321 | Loss: 0.3969
#    % Time:  733s | Batch:  331 | Loss: 0.3820
#    % Time:  755s | Batch:  341 | Loss: 0.4100
#    % Time:  777s | Batch:  351 | Loss: 0.3981
#    % Time:  799s | Batch:  361 | Loss: 0.3987
#    % Time:  821s | Batch:  371 | Loss: 0.3421
#    % Time:  843s | Batch:  381 | Loss: 0.3911
#    % Time:  865s | Batch:  391 | Loss: 0.3627
#    % Time:  887s | Batch:  401 | Loss: 0.4234
#    % Time:  910s | Batch:  411 | Loss: 0.3406
#    % Time:  932s | Batch:  421 | Loss: 0.4316
#    % Time:  954s | Batch:  431 | Loss: 0.3748
#    % Time:  976s | Batch:  441 | Loss: 0.3380
#    % Time:  999s | Batch:  451 | Loss: 0.3994
#    % Time: 1021s | Batch:  461 | Loss: 0.3906
#    % Time: 1043s | Batch:  471 | Loss: 0.3390
#    % Time: 1066s | Batch:  481 | Loss: 0.3934
#    % Time: 1088s | Batch:  491 | Loss: 0.3937
#    % Time: 1110s | Batch:  501 | Loss: 0.4540
#    % Time: 1132s | Batch:  511 | Loss: 0.3606
#    % Time: 1155s | Batch:  521 | Loss: 0.3717
#    % Time: 1177s | Batch:  531 | Loss: 0.4044
#    % Time: 1199s | Batch:  541 | Loss: 0.3742
#    % Time: 1221s | Batch:  551 | Loss: 0.3760
#    % Time: 1243s | Batch:  561 | Loss: 0.3709
#    % Time: 1265s | Batch:  571 | Loss: 0.3871
#    % Time: 1287s | Batch:  581 | Loss: 0.3768
#    % Time: 1308s | Batch:  591 | Loss: 0.3603
#    % Time: 1330s | Batch:  601 | Loss: 0.3608
#    % Time: 1352s | Batch:  611 | Loss: 0.3912
#    % Time: 1374s | Batch:  621 | Loss: 0.3822
#    % Time: 1396s | Batch:  631 | Loss: 0.3707
#    % Time: 1418s | Batch:  641 | Loss: 0.4000
#    % Time: 1440s | Batch:  651 | Loss: 0.4351
#    % Time: 1462s | Batch:  661 | Loss: 0.3583
#    % Time: 1484s | Batch:  671 | Loss: 0.3950
#    % Time: 1506s | Batch:  681 | Loss: 0.3756
#    % Time: 1528s | Batch:  691 | Loss: 0.3761
#    % Time: 1550s | Batch:  701 | Loss: 0.4134
#    % Time: 1573s | Batch:  711 | Loss: 0.3880
#    % Time: 1595s | Batch:  721 | Loss: 0.3765
#    % Time: 1617s | Batch:  731 | Loss: 0.3940
#    % Time: 1639s | Batch:  741 | Loss: 0.4138
#    % Time: 1662s | Batch:  751 | Loss: 0.3584
#    % Time: 1684s | Batch:  761 | Loss: 0.3792
#    % Time: 1706s | Batch:  771 | Loss: 0.3880
#    % Time: 1728s | Batch:  781 | Loss: 0.3834
#    % Time: 1751s | Batch:  791 | Loss: 0.3774
#    % Time: 1773s | Batch:  801 | Loss: 0.3993
#    % Time: 1795s | Batch:  811 | Loss: 0.4200
#    % Time: 1817s | Batch:  821 | Loss: 0.4070
#    % Time: 1840s | Batch:  831 | Loss: 0.3679
#    % Time: 1862s | Batch:  841 | Loss: 0.3853
#    % Time: 1884s | Batch:  851 | Loss: 0.3668
#    % Time: 1906s | Batch:  861 | Loss: 0.4001
#    % Time: 1929s | Batch:  871 | Loss: 0.3606
#    % Time: 1951s | Batch:  881 | Loss: 0.3968
#    % Time: 1973s | Batch:  891 | Loss: 0.3363
#    % Time: 1995s | Batch:  901 | Loss: 0.3949
#    % Time: 2017s | Batch:  911 | Loss: 0.3875
#    % Time: 2039s | Batch:  921 | Loss: 0.3321
#    % Time: 2062s | Batch:  931 | Loss: 0.3967
#    % Time: 2084s | Batch:  941 | Loss: 0.3858
#    % Time: 2106s | Batch:  951 | Loss: 0.3895
#    % Time: 2128s | Batch:  961 | Loss: 0.3559
#    % Time: 2150s | Batch:  971 | Loss: 0.3911
#    % Time: 2172s | Batch:  981 | Loss: 0.3700
#    % Time: 2194s | Batch:  991 | Loss: 0.3947
#    % Time: 2216s | Batch: 1001 | Loss: 0.3786
#    % Time: 2238s | Batch: 1011 | Loss: 0.4055
#    % Time: 2260s | Batch: 1021 | Loss: 0.4093
#    % Time: 2282s | Batch: 1031 | Loss: 0.4074
#    % Time: 2303s | Batch: 1041 | Loss: 0.3810
#    % Time: 2325s | Batch: 1051 | Loss: 0.3948
#    % Time: 2347s | Batch: 1061 | Loss: 0.3515
#    % Time: 2369s | Batch: 1071 | Loss: 0.3956
#    % Time: 2391s | Batch: 1081 | Loss: 0.3817
#    % Time: 2412s | Batch: 1091 | Loss: 0.3505
#    % Time: 2435s | Batch: 1101 | Loss: 0.4062
#    % Time: 2457s | Batch: 1111 | Loss: 0.3832
#    % Time: 2479s | Batch: 1121 | Loss: 0.3896
#    % Time: 2501s | Batch: 1131 | Loss: 0.3527
# ==========
#    % Epoch: 2 | Time: 2508s | Train loss: 0.3865 | Val loss: 29.2373
# ==========
# => EPOCH 3
#    % Time:    2s | Batch:    1 | Loss: 0.3908
#    % Time:   24s | Batch:   11 | Loss: 0.3767
#    % Time:   46s | Batch:   21 | Loss: 0.3963
#    % Time:   68s | Batch:   31 | Loss: 0.3684
#    % Time:   90s | Batch:   41 | Loss: 0.3997
#    % Time:  112s | Batch:   51 | Loss: 0.3686
#    % Time:  134s | Batch:   61 | Loss: 0.3946
#    % Time:  156s | Batch:   71 | Loss: 0.3961
#    % Time:  178s | Batch:   81 | Loss: 0.3526
#    % Time:  201s | Batch:   91 | Loss: 0.3833
#    % Time:  223s | Batch:  101 | Loss: 0.3624
#    % Time:  245s | Batch:  111 | Loss: 0.3838
#    % Time:  268s | Batch:  121 | Loss: 0.4157
#    % Time:  289s | Batch:  131 | Loss: 0.4003
#    % Time:  310s | Batch:  141 | Loss: 0.3933
#    % Time:  332s | Batch:  151 | Loss: 0.3668
#    % Time:  354s | Batch:  161 | Loss: 0.3798
#    % Time:  376s | Batch:  171 | Loss: 0.3694
#    % Time:  398s | Batch:  181 | Loss: 0.4027
#    % Time:  420s | Batch:  191 | Loss: 0.3752
#    % Time:  442s | Batch:  201 | Loss: 0.4067
#    % Time:  465s | Batch:  211 | Loss: 0.3767
#    % Time:  487s | Batch:  221 | Loss: 0.3937
#    % Time:  508s | Batch:  231 | Loss: 0.3843
#    % Time:  530s | Batch:  241 | Loss: 0.4021
#    % Time:  552s | Batch:  251 | Loss: 0.3821
#    % Time:  574s | Batch:  261 | Loss: 0.3656
#    % Time:  596s | Batch:  271 | Loss: 0.3703
#    % Time:  619s | Batch:  281 | Loss: 0.3804
#    % Time:  641s | Batch:  291 | Loss: 0.3568
#    % Time:  662s | Batch:  301 | Loss: 0.3875
#    % Time:  684s | Batch:  311 | Loss: 0.4092
#    % Time:  706s | Batch:  321 | Loss: 0.3942
#    % Time:  726s | Batch:  331 | Loss: 0.3781
#    % Time:  748s | Batch:  341 | Loss: 0.3818
#    % Time:  770s | Batch:  351 | Loss: 0.3696
#    % Time:  792s | Batch:  361 | Loss: 0.3941
#    % Time:  814s | Batch:  371 | Loss: 0.3770
#    % Time:  837s | Batch:  381 | Loss: 0.3590
#    % Time:  859s | Batch:  391 | Loss: 0.3800
#    % Time:  881s | Batch:  401 | Loss: 0.3613
#    % Time:  903s | Batch:  411 | Loss: 0.3602
#    % Time:  925s | Batch:  421 | Loss: 0.3689
#    % Time:  947s | Batch:  431 | Loss: 0.3841
#    % Time:  969s | Batch:  441 | Loss: 0.3799
#    % Time:  991s | Batch:  451 | Loss: 0.3472
#    % Time: 1013s | Batch:  461 | Loss: 0.3848
#    % Time: 1035s | Batch:  471 | Loss: 0.3764
#    % Time: 1057s | Batch:  481 | Loss: 0.3887
#    % Time: 1080s | Batch:  491 | Loss: 0.3960
#    % Time: 1102s | Batch:  501 | Loss: 0.3531
#    % Time: 1124s | Batch:  511 | Loss: 0.3826
#    % Time: 1146s | Batch:  521 | Loss: 0.3580
#    % Time: 1168s | Batch:  531 | Loss: 0.3761
#    % Time: 1190s | Batch:  541 | Loss: 0.3799
#    % Time: 1212s | Batch:  551 | Loss: 0.3800
#    % Time: 1234s | Batch:  561 | Loss: 0.4238
#    % Time: 1256s | Batch:  571 | Loss: 0.4192
#    % Time: 1278s | Batch:  581 | Loss: 0.3682
#    % Time: 1300s | Batch:  591 | Loss: 0.4050
#    % Time: 1322s | Batch:  601 | Loss: 0.3840
#    % Time: 1344s | Batch:  611 | Loss: 0.3274
#    % Time: 1366s | Batch:  621 | Loss: 0.3902
#    % Time: 1388s | Batch:  631 | Loss: 0.4089
#    % Time: 1410s | Batch:  641 | Loss: 0.3960
#    % Time: 1432s | Batch:  651 | Loss: 0.3812
#    % Time: 1454s | Batch:  661 | Loss: 0.3848
#    % Time: 1476s | Batch:  671 | Loss: 0.4117
#    % Time: 1499s | Batch:  681 | Loss: 0.3915
#    % Time: 1521s | Batch:  691 | Loss: 0.3646
#    % Time: 1543s | Batch:  701 | Loss: 0.3749
#    % Time: 1566s | Batch:  711 | Loss: 0.4028
#    % Time: 1588s | Batch:  721 | Loss: 0.3933
#    % Time: 1610s | Batch:  731 | Loss: 0.4027
#    % Time: 1632s | Batch:  741 | Loss: 0.3630
#    % Time: 1655s | Batch:  751 | Loss: 0.3888
#    % Time: 1677s | Batch:  761 | Loss: 0.3554
#    % Time: 1699s | Batch:  771 | Loss: 0.3686
#    % Time: 1721s | Batch:  781 | Loss: 0.3995
#    % Time: 1744s | Batch:  791 | Loss: 0.3781
#    % Time: 1766s | Batch:  801 | Loss: 0.3775
#    % Time: 1788s | Batch:  811 | Loss: 0.4095
#    % Time: 1811s | Batch:  821 | Loss: 0.3915
#    % Time: 1833s | Batch:  831 | Loss: 0.3918
#    % Time: 1855s | Batch:  841 | Loss: 0.3780
#    % Time: 1877s | Batch:  851 | Loss: 0.3923
#    % Time: 1899s | Batch:  861 | Loss: 0.3815
#    % Time: 1921s | Batch:  871 | Loss: 0.3802
#    % Time: 1943s | Batch:  881 | Loss: 0.3820
#    % Time: 1965s | Batch:  891 | Loss: 0.3647
#    % Time: 1988s | Batch:  901 | Loss: 0.4073
#    % Time: 2010s | Batch:  911 | Loss: 0.4051
#    % Time: 2032s | Batch:  921 | Loss: 0.3638
#    % Time: 2054s | Batch:  931 | Loss: 0.4116
#    % Time: 2077s | Batch:  941 | Loss: 0.3479
#    % Time: 2099s | Batch:  951 | Loss: 0.3602
#    % Time: 2121s | Batch:  961 | Loss: 0.3647
#    % Time: 2143s | Batch:  971 | Loss: 0.3831
#    % Time: 2165s | Batch:  981 | Loss: 0.4304
#    % Time: 2187s | Batch:  991 | Loss: 0.3810
#    % Time: 2209s | Batch: 1001 | Loss: 0.3642
#    % Time: 2231s | Batch: 1011 | Loss: 0.3676
#    % Time: 2253s | Batch: 1021 | Loss: 0.3617
#    % Time: 2275s | Batch: 1031 | Loss: 0.3617
#    % Time: 2297s | Batch: 1041 | Loss: 0.4071
#    % Time: 2319s | Batch: 1051 | Loss: 0.3589
#    % Time: 2341s | Batch: 1061 | Loss: 0.4215
#    % Time: 2363s | Batch: 1071 | Loss: 0.3866
#    % Time: 2385s | Batch: 1081 | Loss: 0.3795
#    % Time: 2407s | Batch: 1091 | Loss: 0.3980
#    % Time: 2429s | Batch: 1101 | Loss: 0.3681
#    % Time: 2451s | Batch: 1111 | Loss: 0.3386
#    % Time: 2473s | Batch: 1121 | Loss: 0.3631
#    % Time: 2495s | Batch: 1131 | Loss: 0.4093
# ==========
#    % Epoch: 3 | Time: 2502s | Train loss: 0.3831 | Val loss: 28.9000
# ==========
# => EPOCH 4
#    % Time:    2s | Batch:    1 | Loss: 0.3834
#    % Time:   24s | Batch:   11 | Loss: 0.3853
#    % Time:   46s | Batch:   21 | Loss: 0.3506
#    % Time:   68s | Batch:   31 | Loss: 0.4111
#    % Time:   90s | Batch:   41 | Loss: 0.3889
#    % Time:  112s | Batch:   51 | Loss: 0.4043
#    % Time:  135s | Batch:   61 | Loss: 0.3892
#    % Time:  157s | Batch:   71 | Loss: 0.3770
#    % Time:  179s | Batch:   81 | Loss: 0.3747
#    % Time:  201s | Batch:   91 | Loss: 0.3881
#    % Time:  224s | Batch:  101 | Loss: 0.3694
#    % Time:  246s | Batch:  111 | Loss: 0.3702
#    % Time:  268s | Batch:  121 | Loss: 0.4011
#    % Time:  290s | Batch:  131 | Loss: 0.3702
#    % Time:  313s | Batch:  141 | Loss: 0.3506
#    % Time:  335s | Batch:  151 | Loss: 0.3607
#    % Time:  357s | Batch:  161 | Loss: 0.3649
#    % Time:  380s | Batch:  171 | Loss: 0.3935
#    % Time:  402s | Batch:  181 | Loss: 0.3582
#    % Time:  424s | Batch:  191 | Loss: 0.3790
#    % Time:  446s | Batch:  201 | Loss: 0.3745
#    % Time:  469s | Batch:  211 | Loss: 0.3646
#    % Time:  491s | Batch:  221 | Loss: 0.4084
#    % Time:  513s | Batch:  231 | Loss: 0.3673
#    % Time:  535s | Batch:  241 | Loss: 0.3730
#    % Time:  558s | Batch:  251 | Loss: 0.3926
#    % Time:  580s | Batch:  261 | Loss: 0.3824
#    % Time:  602s | Batch:  271 | Loss: 0.4027
#    % Time:  624s | Batch:  281 | Loss: 0.3483
#    % Time:  647s | Batch:  291 | Loss: 0.3718
#    % Time:  669s | Batch:  301 | Loss: 0.3764
#    % Time:  691s | Batch:  311 | Loss: 0.3630
#    % Time:  713s | Batch:  321 | Loss: 0.3726
#    % Time:  735s | Batch:  331 | Loss: 0.3930
#    % Time:  757s | Batch:  341 | Loss: 0.3661
#    % Time:  779s | Batch:  351 | Loss: 0.4180
#    % Time:  801s | Batch:  361 | Loss: 0.4024
#    % Time:  823s | Batch:  371 | Loss: 0.3723
#    % Time:  846s | Batch:  381 | Loss: 0.3751
#    % Time:  868s | Batch:  391 | Loss: 0.3880
#    % Time:  890s | Batch:  401 | Loss: 0.3978
#    % Time:  912s | Batch:  411 | Loss: 0.3798
#    % Time:  934s | Batch:  421 | Loss: 0.3715
#    % Time:  956s | Batch:  431 | Loss: 0.3650
#    % Time:  978s | Batch:  441 | Loss: 0.3666
#    % Time: 1000s | Batch:  451 | Loss: 0.3909
#    % Time: 1022s | Batch:  461 | Loss: 0.3662
#    % Time: 1044s | Batch:  471 | Loss: 0.3528
#    % Time: 1066s | Batch:  481 | Loss: 0.3737
#    % Time: 1088s | Batch:  491 | Loss: 0.3900
#    % Time: 1111s | Batch:  501 | Loss: 0.3925
#    % Time: 1133s | Batch:  511 | Loss: 0.3853
#    % Time: 1155s | Batch:  521 | Loss: 0.3398
#    % Time: 1177s | Batch:  531 | Loss: 0.3666
#    % Time: 1199s | Batch:  541 | Loss: 0.3914
#    % Time: 1220s | Batch:  551 | Loss: 0.4192
#    % Time: 1242s | Batch:  561 | Loss: 0.3925
#    % Time: 1264s | Batch:  571 | Loss: 0.3603
#    % Time: 1287s | Batch:  581 | Loss: 0.3713
#    % Time: 1309s | Batch:  591 | Loss: 0.4013
#    % Time: 1331s | Batch:  601 | Loss: 0.3916
#    % Time: 1353s | Batch:  611 | Loss: 0.3366
#    % Time: 1376s | Batch:  621 | Loss: 0.3809
#    % Time: 1398s | Batch:  631 | Loss: 0.3869
#    % Time: 1420s | Batch:  641 | Loss: 0.3502
#    % Time: 1442s | Batch:  651 | Loss: 0.3547
#    % Time: 1464s | Batch:  661 | Loss: 0.3838
#    % Time: 1486s | Batch:  671 | Loss: 0.4148
#    % Time: 1509s | Batch:  681 | Loss: 0.3707
#    % Time: 1531s | Batch:  691 | Loss: 0.3534
#    % Time: 1553s | Batch:  701 | Loss: 0.4006
#    % Time: 1576s | Batch:  711 | Loss: 0.4141
#    % Time: 1598s | Batch:  721 | Loss: 0.4113
#    % Time: 1620s | Batch:  731 | Loss: 0.3681
#    % Time: 1642s | Batch:  741 | Loss: 0.3878
#    % Time: 1664s | Batch:  751 | Loss: 0.4110
#    % Time: 1686s | Batch:  761 | Loss: 0.3483
#    % Time: 1708s | Batch:  771 | Loss: 0.3886
#    % Time: 1730s | Batch:  781 | Loss: 0.3742
#    % Time: 1752s | Batch:  791 | Loss: 0.3822
#    % Time: 1775s | Batch:  801 | Loss: 0.4104
#    % Time: 1796s | Batch:  811 | Loss: 0.3822
#    % Time: 1819s | Batch:  821 | Loss: 0.3520
#    % Time: 1841s | Batch:  831 | Loss: 0.3652
#    % Time: 1863s | Batch:  841 | Loss: 0.3694
#    % Time: 1885s | Batch:  851 | Loss: 0.3909
#    % Time: 1906s | Batch:  861 | Loss: 0.3738
#    % Time: 1928s | Batch:  871 | Loss: 0.3688
#    % Time: 1950s | Batch:  881 | Loss: 0.3790
#    % Time: 1973s | Batch:  891 | Loss: 0.3678
#    % Time: 1995s | Batch:  901 | Loss: 0.3748
#    % Time: 2017s | Batch:  911 | Loss: 0.3822
#    % Time: 2039s | Batch:  921 | Loss: 0.3675
#    % Time: 2062s | Batch:  931 | Loss: 0.3668
#    % Time: 2084s | Batch:  941 | Loss: 0.3402
#    % Time: 2106s | Batch:  951 | Loss: 0.3666
#    % Time: 2128s | Batch:  961 | Loss: 0.3512
#    % Time: 2151s | Batch:  971 | Loss: 0.4069
#    % Time: 2173s | Batch:  981 | Loss: 0.3972
#    % Time: 2195s | Batch:  991 | Loss: 0.3797
#    % Time: 2217s | Batch: 1001 | Loss: 0.3884
#    % Time: 2239s | Batch: 1011 | Loss: 0.3810
#    % Time: 2261s | Batch: 1021 | Loss: 0.3978
#    % Time: 2283s | Batch: 1031 | Loss: 0.3652
#    % Time: 2305s | Batch: 1041 | Loss: 0.3489
#    % Time: 2327s | Batch: 1051 | Loss: 0.3391
#    % Time: 2349s | Batch: 1061 | Loss: 0.4020
#    % Time: 2371s | Batch: 1071 | Loss: 0.3577
#    % Time: 2393s | Batch: 1081 | Loss: 0.3531
#    % Time: 2415s | Batch: 1091 | Loss: 0.3870
#    % Time: 2438s | Batch: 1101 | Loss: 0.3395
#    % Time: 2460s | Batch: 1111 | Loss: 0.3881
#    % Time: 2482s | Batch: 1121 | Loss: 0.3932
#    % Time: 2505s | Batch: 1131 | Loss: 0.4010
# ==========
#    % Epoch: 4 | Time: 2512s | Train loss: 0.3784 | Val loss: 28.6540
# ==========
# => EPOCH 5
#    % Time:    2s | Batch:    1 | Loss: 0.3876
#    % Time:   24s | Batch:   11 | Loss: 0.3816
#    % Time:   46s | Batch:   21 | Loss: 0.4079
#    % Time:   69s | Batch:   31 | Loss: 0.3621
#    % Time:   91s | Batch:   41 | Loss: 0.3993
#    % Time:  113s | Batch:   51 | Loss: 0.3768
#    % Time:  135s | Batch:   61 | Loss: 0.3812
#    % Time:  157s | Batch:   71 | Loss: 0.3713
#    % Time:  179s | Batch:   81 | Loss: 0.3622
#    % Time:  200s | Batch:   91 | Loss: 0.3407
#    % Time:  222s | Batch:  101 | Loss: 0.3555
#    % Time:  244s | Batch:  111 | Loss: 0.3854
#    % Time:  266s | Batch:  121 | Loss: 0.3490
#    % Time:  288s | Batch:  131 | Loss: 0.3827
#    % Time:  310s | Batch:  141 | Loss: 0.3861
#    % Time:  332s | Batch:  151 | Loss: 0.3689
#    % Time:  354s | Batch:  161 | Loss: 0.3928
#    % Time:  376s | Batch:  171 | Loss: 0.3993
#    % Time:  399s | Batch:  181 | Loss: 0.3768
#    % Time:  421s | Batch:  191 | Loss: 0.3605
#    % Time:  443s | Batch:  201 | Loss: 0.3757
#    % Time:  466s | Batch:  211 | Loss: 0.3782
#    % Time:  488s | Batch:  221 | Loss: 0.3843
#    % Time:  510s | Batch:  231 | Loss: 0.3478
#    % Time:  532s | Batch:  241 | Loss: 0.3463
#    % Time:  554s | Batch:  251 | Loss: 0.3761
#    % Time:  577s | Batch:  261 | Loss: 0.3602
#    % Time:  599s | Batch:  271 | Loss: 0.3689
#    % Time:  621s | Batch:  281 | Loss: 0.3591
#    % Time:  643s | Batch:  291 | Loss: 0.3758
#    % Time:  665s | Batch:  301 | Loss: 0.3807
#    % Time:  688s | Batch:  311 | Loss: 0.4075
#    % Time:  710s | Batch:  321 | Loss: 0.3438
#    % Time:  732s | Batch:  331 | Loss: 0.3494
#    % Time:  754s | Batch:  341 | Loss: 0.3907
#    % Time:  776s | Batch:  351 | Loss: 0.3852
#    % Time:  798s | Batch:  361 | Loss: 0.3557
#    % Time:  820s | Batch:  371 | Loss: 0.3988
#    % Time:  842s | Batch:  381 | Loss: 0.4013
#    % Time:  865s | Batch:  391 | Loss: 0.3884
#    % Time:  887s | Batch:  401 | Loss: 0.3703
#    % Time:  909s | Batch:  411 | Loss: 0.3352
#    % Time:  931s | Batch:  421 | Loss: 0.3695
#    % Time:  953s | Batch:  431 | Loss: 0.4139
#    % Time:  975s | Batch:  441 | Loss: 0.3502
#    % Time:  997s | Batch:  451 | Loss: 0.3628
#    % Time: 1019s | Batch:  461 | Loss: 0.3745
#    % Time: 1041s | Batch:  471 | Loss: 0.3501
#    % Time: 1064s | Batch:  481 | Loss: 0.3865
#    % Time: 1086s | Batch:  491 | Loss: 0.3899
#    % Time: 1108s | Batch:  501 | Loss: 0.3729
#    % Time: 1130s | Batch:  511 | Loss: 0.4207
#    % Time: 1152s | Batch:  521 | Loss: 0.3647
#    % Time: 1174s | Batch:  531 | Loss: 0.4361
#    % Time: 1196s | Batch:  541 | Loss: 0.3717
#    % Time: 1218s | Batch:  551 | Loss: 0.4046
#    % Time: 1240s | Batch:  561 | Loss: 0.4220
#    % Time: 1262s | Batch:  571 | Loss: 0.3780
#    % Time: 1284s | Batch:  581 | Loss: 0.3854
#    % Time: 1306s | Batch:  591 | Loss: 0.3841
#    % Time: 1328s | Batch:  601 | Loss: 0.3367
#    % Time: 1350s | Batch:  611 | Loss: 0.4066
#    % Time: 1372s | Batch:  621 | Loss: 0.3831
#    % Time: 1395s | Batch:  631 | Loss: 0.3662
#    % Time: 1417s | Batch:  641 | Loss: 0.3686
#    % Time: 1439s | Batch:  651 | Loss: 0.4208
#    % Time: 1461s | Batch:  661 | Loss: 0.3850
#    % Time: 1483s | Batch:  671 | Loss: 0.3845
#    % Time: 1506s | Batch:  681 | Loss: 0.3640
#    % Time: 1528s | Batch:  691 | Loss: 0.3809
#    % Time: 1550s | Batch:  701 | Loss: 0.3735
#    % Time: 1573s | Batch:  711 | Loss: 0.3718
#    % Time: 1595s | Batch:  721 | Loss: 0.4053
#    % Time: 1617s | Batch:  731 | Loss: 0.3374
#    % Time: 1639s | Batch:  741 | Loss: 0.3570
#    % Time: 1661s | Batch:  751 | Loss: 0.3876
#    % Time: 1683s | Batch:  761 | Loss: 0.4040
#    % Time: 1706s | Batch:  771 | Loss: 0.4023
#    % Time: 1728s | Batch:  781 | Loss: 0.3703
#    % Time: 1750s | Batch:  791 | Loss: 0.3826
#    % Time: 1772s | Batch:  801 | Loss: 0.3727
#    % Time: 1794s | Batch:  811 | Loss: 0.3808
#    % Time: 1816s | Batch:  821 | Loss: 0.3789
#    % Time: 1838s | Batch:  831 | Loss: 0.3647
#    % Time: 1860s | Batch:  841 | Loss: 0.3732
#    % Time: 1883s | Batch:  851 | Loss: 0.3710
#    % Time: 1905s | Batch:  861 | Loss: 0.3805
#    % Time: 1927s | Batch:  871 | Loss: 0.3780
#    % Time: 1949s | Batch:  881 | Loss: 0.3873
#    % Time: 1972s | Batch:  891 | Loss: 0.3767
#    % Time: 1994s | Batch:  901 | Loss: 0.3835
#    % Time: 2016s | Batch:  911 | Loss: 0.3555
#    % Time: 2039s | Batch:  921 | Loss: 0.3695
#    % Time: 2061s | Batch:  931 | Loss: 0.3629
#    % Time: 2083s | Batch:  941 | Loss: 0.3944
#    % Time: 2106s | Batch:  951 | Loss: 0.3850
#    % Time: 2128s | Batch:  961 | Loss: 0.3916
#    % Time: 2150s | Batch:  971 | Loss: 0.3893
#    % Time: 2172s | Batch:  981 | Loss: 0.3858
#    % Time: 2194s | Batch:  991 | Loss: 0.3718
#    % Time: 2216s | Batch: 1001 | Loss: 0.3653
#    % Time: 2239s | Batch: 1011 | Loss: 0.3830
#    % Time: 2261s | Batch: 1021 | Loss: 0.3738
#    % Time: 2283s | Batch: 1031 | Loss: 0.3640
#    % Time: 2305s | Batch: 1041 | Loss: 0.3877
#    % Time: 2327s | Batch: 1051 | Loss: 0.3796
#    % Time: 2349s | Batch: 1061 | Loss: 0.3920
#    % Time: 2371s | Batch: 1071 | Loss: 0.3661
#    % Time: 2393s | Batch: 1081 | Loss: 0.4371
#    % Time: 2415s | Batch: 1091 | Loss: 0.3920
#    % Time: 2437s | Batch: 1101 | Loss: 0.3406
#    % Time: 2460s | Batch: 1111 | Loss: 0.3789
#    % Time: 2482s | Batch: 1121 | Loss: 0.4024
#    % Time: 2504s | Batch: 1131 | Loss: 0.4085
# ==========
#    % Epoch: 5 | Time: 2511s | Train loss: 0.3778 | Val loss: 28.6730
# ==========

# %% [markdown]
# ### test

# %%
prediction = forecast(scaled_data, scaler, model)
prediction_file = os.path.join(args.intermediate_path,
                               'prediction_seed{}.pkl'.format(args.seed))

with open(prediction_file, 'wb') as f:
    pickle.dump(prediction, f)
